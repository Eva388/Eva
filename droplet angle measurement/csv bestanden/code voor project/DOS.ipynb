# %%
import pandas as pd
import os
from os import listdir
import numpy as np
import matplotlib.pyplot as plt

# %%
listdir("./")
# Out:
# ['.ipynb_checkpoints',
#  'code',
#  'codeplotten.py',
#  'codetest.py',
#  'CPC.csv',
#  'Das',
#  'DOS _0.5_and_1_on_PMDS.csv',
#  'Dos.csv',
#  'DOS.ipynb',
#  'Dos_0.5and_1_on_Steel.csv',
#  'SDS.csv',
#  'test.py',
#  'triton.csv',
#  'triton2.csv',
#  'triton3.csv',
#  'Untitled.ipynb',
#  'water_glas.csv',
#  'water_PDMS.csv',
#  'water_staal.csv']

# %%
df = pd.read_csv("./Dos.csv", sep = ";")
df["Dos"].unique()
# Out:
# array([0.5, 1. , 3. , 5. ])

# %%
df
# Out:
#     Dos  tijd in min  hoek  error
# 0   0.5            2  24.3   0.01
# 1   0.5            4  24.0   0.02
# 2   0.5            6  23.9   0.09
# 3   0.5            8  23.2   0.06
# 4   0.5           10  22.9   0.01
# 5   0.5           15  22.8   0.02
# 6   0.5           20  22.7   0.02
# 7   0.5           25  22.7   0.01
# 8   0.5           60  22.2   0.07
# 9   1.0            2  17.9   0.02
# 10  1.0            4  16.8   0.19
# 11  1.0            6  15.8   0.05
# 12  1.0            8  15.8   0.03
# 13  1.0           10  15.3   0.07
# 14  1.0           15  14.9   0.09
# 15  1.0           20  14.8   0.18
# 16  1.0           25  14.5   0.06
# 17  1.0           60  13.9   0.19
# 18  3.0            2  14.1   0.05
# 19  3.0            4  12.9   0.06
# 20  3.0            6  12.0   0.06
# 21  3.0            8   8.9   0.78
# 22  3.0           10   9.1   1.57
# 23  3.0           15   9.7   1.51
# 24  3.0           20   9.9   0.43
# 25  3.0           25   8.7   1.06
# ...

# %%
df_list = list()
for conc in df["Dos"].unique():
    df_list.append(df[df["Dos"] == conc])

# %%
data_dict = dict()
for frame in df_list:
    time = frame["tijd in min"]
    angle = frame["hoek"]
    error = frame["error"]
    data_dict[frame["Dos"].unique()[0]] = (time,angle,error)

# %%
for name, values in data_dict.items():
    plt.errorbar(values[0],values[1],values[2], linestyle = "None", label = f"{name}%", marker = "o")
    
plt.legend()
plt.xlim(0,70)
plt.ylim(0,30)

plt.xlabel('time in minutes')
plt.ylabel('angle')

plt.title('DOSS')
plt.savefig('DOSS')

# %%
fig,ax = plt.subplots(4,1, figsize = (8,12))
ax_idx = 0

for name, values in data_dict.items():
    ax[ax_idx].errorbar(values[0],values[1],values[2], linestyle = "None", label = f"{name}%", marker = "o")
    ax[ax_idx].set_xlim(0,70)
    ax[ax_idx].set_ylim(0,30)
    ax[ax_idx].set_title(f"Dos solution with {name}% concentration")
    ax_idx += 1
